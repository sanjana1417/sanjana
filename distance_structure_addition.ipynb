# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjana1417/sanjana/blob/main/distance_structure_addition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile distance.c
# #include <stdio.h>
#
# struct distance {
#     int feet;
#     float inch;
# };
#
# int main() {
#     struct distance d1, d2, sum;
#
#     printf("Enter first distance (feet inch): ");
#     scanf("%d%f", &d1.feet, &d1.inch);
#
#     printf("Enter second distance (feet inch): ");
#     scanf("%d%f", &d2.feet, &d2.inch);
#
#     sum.feet = d1.feet + d2.feet;
#     sum.inch = d1.inch + d2.inch;
#
#     while (sum.inch >= 12.0) {
#         sum.inch -= 12.0;
#         sum.feet++;
#     }
#
#     printf("Sum of distances = %d' %.2f\"\n", sum.feet, sum.inch);
#     return 0;
# }
# Out:
# Writing distance.c

# %%
# !gcc distance.c -o distance
# !./distance
# Out:
# Enter first distance (feet inch): 32
# 45
# Enter second distance (feet inch): 38 47
# Sum of distances = 77' 8.00"
