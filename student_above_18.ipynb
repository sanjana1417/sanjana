# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjana1417/sanjana/blob/main/student_above_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile student.c
# #include <stdio.h>
#
# struct student {
#     char name[50];
#     int roll;
#     int age;
# };
#
# int main() {
#     struct student s[10];
#     int count = 0;
#
#     for (int i = 0; i < 10; i++) {
#         printf("Enter name, roll, age of student %d: ", i + 1);
#         scanf("%s%d%d", s[i].name, &s[i].roll, &s[i].age);
#         if (s[i].age > 18) count++;
#     }
#
#     printf("\nNumber of students above 18: %d", count);
#     return 0;
# }
# Out:
# Writing student.c

# %%
# !gcc student.c -o student
# !./student
# Out:
# Enter name, roll, age of student 1: sanjana 22 23
# Enter name, roll, age of student 2: maanvi 32 21
# Enter name, roll, age of student 3: kiran 43 21
# Enter name, roll, age of student 4: setia 21 30
# Enter name, roll, age of student 5: lado 17 19
# Enter name, roll, age of student 6: knchnn 23 16
# Enter name, roll, age of student 7: khusii 34 32
# Enter name, roll, age of student 8: priyanka 18 18
# Enter name, roll, age of student 9: teena 19 24
# Enter name, roll, age of student 10: shrutii 26 12
#
# Number of students above 18: 7
