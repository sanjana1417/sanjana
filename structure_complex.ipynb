# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjana1417/sanjana/blob/main/structure_complex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Complex code**

# %%
# %%writefile complex.c
# #include <stdio.h>
#
# struct complex { float real, imag; };
#
# int main() {
#     struct complex c1, c2, sum;
#
#     printf("Enter first complex number (real imag): ");
#     scanf("%f%f", &c1.real, &c1.imag);
#
#     printf("Enter second complex number (real imag): ");
#     scanf("%f%f", &c2.real, &c2.imag);
#
#     sum.real = c1.real + c2.real;
#     sum.imag = c1.imag + c2.imag;
#
#     printf("Sum = %.2f + %.2fi", sum.real, sum.imag);
#     return 0;
# }
# Out:
# Writing complex.c

# %%
# !gcc complex.c -o complex
# !./complex
# Out:
# Enter first complex number (real imag): 1.2 3.5
# Enter second complex number (real imag): 2.5 4.0
# Sum = 3.70 + 7.50i
