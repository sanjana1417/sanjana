# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjana1417/sanjana/blob/main/factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile factorial.c
# #include <stdio.h>
#
# long long factorial(int n) {
#     if (n == 0 || n == 1) {
#         return 1;   // base case
#     }
#     return n * factorial(n - 1);  // recursive call
# }
#
# int main() {
#     int num;
#     printf("Enter a number: ");
#     scanf("%d", &num);
#
#     if (num < 0) {
#         printf("Factorial of negative numbers is not defined.\n");
#     } else {
#         printf("Factorial of %d = %lld\n", num, factorial(num));
#     }
#
#     return 0;
# }
# Out:
# Overwriting factorial.c

# %%
# !gcc factorial.c -o factorial
# !./factorial
# Out:
# Enter a number: 7
# Factorial of 7 = 5040
